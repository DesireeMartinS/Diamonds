# %% [markdown]
# Diamonds
# Analyze diamonds by their cut, color, clarity, price, and other attributes
#
# Index counter
# carat - Carat weight of the diamond
# cut - Describe cut quality of the diamond. Quality in increasing order Fair, Good, Very Good, Premium, Ideal
# color - Color of the diamond, with D being the best and J the worst
# clarity - How obvious inclusions are within the diamond:(in order from best to worst, FL = flawless, I3= level 3 inclusions) FL,IF, VVS1, VVS2, VS1, VS2, SI1, SI2, I1, I2, I3
# depth - depth % :The height of a diamond, measured from the culet to the table, divided by its average girdle diameter
# table - table%: The width of the diamond's table expressed as a percentage of its average diameter
# price - the price of the diamond
# x - length mm
# y - width mm
# z - depth mm
#
# Homework:
# Do a correlation and regression of your assigned group dataset. This is an individual assignment!

# %% [markdown]
# Notes:
#
# Using the df.drop([column], axis=1) command: validate changes using df.head() function. The df.columns command will show all columns in the original dataset. To delete columns in the original dataset should add the following parameter: inplace= True
#
# Are there any duplicates?
# dupe = df.duplicated()
# df.loc[dupe]

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt

# %matplotlib inline

# %%
file_location = "diamonds.csv"
dfDiamonds = pd.read_csv(file_location)

# %%
dfDiamonds.head()
# Out:
#    Unnamed: 0  carat      cut color clarity  depth  table  price     x     y  \
# 0           1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1           2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2           3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3           4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4           5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35
#
#       z
# 0  2.43
# 1  2.31
# 2  2.31
# 3  2.63
# 4  2.75

# %%
dfDiamonds.rename(columns={"Unnamed: 0":"Number"}, inplace = True)
dfDiamonds.head()
# Out:
#    Number  carat      cut color clarity  depth  table  price     x     y     z
# 0       1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
sns.lmplot (x="carat",y="price", data= dfDiamonds, fit_reg=False, hue="cut")

# %%
sns.lmplot (x="carat",y="price", data= dfDiamonds, fit_reg=False, hue="color")

# %%
sns.lmplot (x="carat",y="price", data= dfDiamonds, fit_reg=False, hue="clarity")

# %%
sns.boxplot(data= dfDiamonds)

# %%
dfDiamonds2 = dfDiamonds.drop(["Number","price","cut","color","clarity", "depth","table"], axis=1)
dfDiamonds2.head()
# Out:
#    carat     x     y     z
# 0   0.23  3.95  3.98  2.43
# 1   0.21  3.89  3.84  2.31
# 2   0.23  4.05  4.07  2.31
# 3   0.29  4.20  4.23  2.63
# 4   0.31  4.34  4.35  2.75

# %%
sns.boxplot(data= dfDiamonds2)

# %%
dfDiamonds2 = dfDiamonds.drop(["Number","price","cut","color","clarity", "depth","table","y","z"], axis=1)
dfDiamonds2.head()
# Out:
#    carat     x
# 0   0.23  3.95
# 1   0.21  3.89
# 2   0.23  4.05
# 3   0.29  4.20
# 4   0.31  4.34

# %%
sns.boxplot(data= dfDiamonds2)

# %%
sns.violinplot( x= 'carat', y = 'price', data= dfDiamonds)
# Out:
# C:\Users\ElisaMartin\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.violinplot( x= 'color', y = 'price', data= dfDiamonds)

# %%
sns.violinplot( x= 'cut', y = 'price', data= dfDiamonds)

# %%
sns.violinplot( x= 'clarity', y = 'price', data= dfDiamonds)

# %%
sns.swarmplot (x="clarity", y="price", data= dfDiamonds, hue= "cut")

# %%
sns.swarmplot (x="clarity", y="price", data= dfDiamonds, hue= "cut", dodge= True)# dogge separate points by hue

# %%
dfDiamonds.head()
# Out:
#    Number  carat      cut color clarity  depth  table  price     x     y     z
# 0       1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
#Calculate corr
corr= dfDiamonds.corr()

# %%
# Show corr through heatmap
sns.heatmap (corr, vmin=-1, annot= True)

# %%
dfDiamonds3= dfDiamonds.drop(['Number'], axis=1)
dfDiamonds3.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
dfDiamonds3.shape
# Out:
# (53940, 10)

# %%
corr= dfDiamonds3.corr()
sns.heatmap (corr, vmin=-1, annot= True)

# %%
#Price histogram

sns.distplot(dfDiamonds3["price"])
# Out:
# C:\Users\ElisaMartin\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
#Bar plot of X frequency
sns.countplot (x='color', data= dfDiamonds)

plt.xticks(rotation=-45)
# Out:
# (array([0, 1, 2, 3, 4, 5, 6]), <a list of 7 Text xticklabel objects>)

# %%
#Bar plot of X frequency
sns.countplot (x='cut', data= dfDiamonds)

plt.xticks(rotation=-45)
# Out:
# (array([0, 1, 2, 3, 4]), <a list of 5 Text xticklabel objects>)

# %%
#Bar plot of X frequency
sns.countplot (x='clarity', data= dfDiamonds)

plt.xticks(rotation=-45)
# Out:
# (array([0, 1, 2, 3, 4, 5, 6, 7]), <a list of 8 Text xticklabel objects>)

# %%
sns.factorplot( x= 'color', y='price',data= dfDiamonds, hue='cut', col='cut',kind='swarm')
# Out:
# C:\Users\ElisaMartin\Anaconda3\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
sns.pairplot(dfDiamonds, hue='color', size=2.5)
# Out:
# C:\Users\ElisaMartin\Anaconda3\lib\site-packages\seaborn\axisgrid.py:2065: UserWarning: The `size` parameter has been renamed to `height`; pleaes update your code.
#   warnings.warn(msg, UserWarning)
# C:\Users\ElisaMartin\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.pairplot(dfDiamonds, hue='cut', size=2.5)
# Out:
# C:\Users\ElisaMartin\Anaconda3\lib\site-packages\seaborn\axisgrid.py:2065: UserWarning: The `size` parameter has been renamed to `height`; pleaes update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.pairplot(dfDiamonds, hue='clarity', size=2.5)
# Out:
# C:\Users\ElisaMartin\Anaconda3\lib\site-packages\seaborn\axisgrid.py:2065: UserWarning: The `size` parameter has been renamed to `height`; pleaes update your code.
#   warnings.warn(msg, UserWarning)
